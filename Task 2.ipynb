# %%
# Task 2: EXPLORATORY DATA ANALYSISI (EDA)

# %%
#  1.Generate summary statistics (mean, median, std, etc.)

# %%
#importing library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading data

# %%
df=pd.read_csv("C:/Users/HP/OneDrive/Desktop/internship/Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# statistical methods of only numeric columns

# %%
df.mean(numeric_only=True)
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
df.min(numeric_only=True)
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# PassengerId    891.0000
# Survived         1.0000
# Pclass           3.0000
# Age             80.0000
# SibSp            8.0000
# Parch            6.0000
# Fare           512.3292
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# PassengerId    257.353842
# Survived         0.486592
# Pclass           0.836071
# Age             14.526497
# SibSp            1.102743
# Parch            0.806057
# Fare            49.693429
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# PassengerId    66231.000000
# Survived           0.236772
# Pclass             0.699015
# Age              211.019125
# SibSp              1.216043
# Parch              0.649728
# Fare            2469.436846
# dtype: float64

# %%
df.sum(numeric_only=True)
# Out:
# PassengerId    397386.0000
# Survived          342.0000
# Pclass           2057.0000
# Age             21205.1700
# SibSp             466.0000
# Parch             340.0000
# Fare            28693.9493
# dtype: float64

# %%
df.count(numeric_only=True)
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Age            714
# SibSp          891
# Parch          891
# Fare           891
# dtype: int64

# %%
df.quantile(numeric_only=True)
# Out:
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# Name: 0.5, dtype: float64

# %%
# correlation and covariance

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.cov(numeric_only=True)
# Out:
#               PassengerId  Survived     Pclass         Age      SibSp  \
# PassengerId  66231.000000 -0.626966  -7.561798  138.696504 -16.325843
# Survived        -0.626966  0.236772  -0.137703   -0.551296  -0.018954
# Pclass          -7.561798 -0.137703   0.699015   -4.496004   0.076599
# Age            138.696504 -0.551296  -4.496004  211.019125  -4.163334
# SibSp          -16.325843 -0.018954   0.076599   -4.163334   1.216043
# Parch           -0.342697  0.032017   0.012429   -2.344191   0.368739
# Fare           161.883369  6.221787 -22.830196   73.849030   8.748734
#
#                 Parch         Fare
# PassengerId -0.342697   161.883369
# Survived     0.032017     6.221787
# Pclass       0.012429   -22.830196
# Age         -2.344191    73.849030
# SibSp        0.368739     8.748734
# Parch        0.649728     8.661052
# Fare         8.661052  2469.436846

# %%
# value counts and unique values of total columns

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                                  Sex     Age   SibSp  Parch  Ticket    Fare      Cabin  Embarked
# 2            1         1       Cumings, Mrs. John Bradley (Florence Briggs Thayer)   female  38.0  1      0      PC 17599  71.2833   C85    C           1
# 572          1         1       Appleton, Mrs. Edward Dale (Charlotte Lamson)         female  53.0  2      0      11769     51.4792   C101   S           1
# 578          1         1       Silvey, Mrs. William Baird (Alice Munger)             female  39.0  1      0      13507     55.9000   E44    S           1
# 582          1         1       Thayer, Mrs. John Borland (Marian Longstreth Morris)  female  39.0  1      1      17421     110.8833  C68    C           1
# 584          0         1       Ross, Mr. John Hugo                                   male    36.0  0      0      13049     40.1250   A10    C           1
# ...

# %%
# info of dataset

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# 2.Create histograms and boxplots for numeric features.

# %%
# selecting the only numerical features

# %%
numeric_cols=df.select_dtypes(include='number').columns

# %%
numeric_cols
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# creatings histograms for numeric columns

# %%
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
# creating box plots of numeric columns

# %%
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
    plt.ylabel(col)
    plt.show()

# %%
#  3.Use pairplot/correlation matrix for feature relationships

# %%
# correlation matrix

# %%
corr_matrix = df.corr(numeric_only=True)
corr_matrix
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# pairplot of total data

# %%
sns.pairplot(df)
plt.show()

# %%
# 4.Identify patterns, trends, or anomalies in the data.

# %%
# identifying patterns by grouping upon mean

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#  Survival Rate by passenger class(pclass) Group

# %%
print(df.groupby('pclass')['survived'].mean())
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
sns.barplot(x='pclass', y='survived', data=df)
plt.title("Survival Rate by Passenger Class")
plt.show()

# %%
# Survival Rate by Age Group

# %%
df['age_group'] = pd.cut(df['age'], bins=[0, 12, 18, 30, 60, 80], labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])
print(df.groupby('age_group')['survived'].mean())
# Out:
# age_group
# Child          0.579710
# Teen           0.428571
# Young Adult    0.355556
# Adult          0.420495
# Senior         0.227273
# Name: survived, dtype: float64
# C:\Users\HP\AppData\Local\Temp\ipykernel_14744\2616068894.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('age_group')['survived'].mean())

# %%
sns.barplot(x='age_group', y='survived', data=df)
# Out:
# <Axes: xlabel='age_group', ylabel='survived'>

# %%
# detecting anomalies

# %%
print(df[df['fare'] > 300])
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
#
#        who  adult_male deck embark_town alive  alone age_group
# 258  woman       False  NaN   Cherbourg   yes   True     Adult
# 679    man        True    B   Cherbourg   yes  False     Adult
# 737    man        True    B   Cherbourg   yes   True     Adult

# %%
sns.boxplot(x='pclass', y='fare', data=df)
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
# 5.Make basic feature-level inferences from visuals

# %%
# Fare vs. Survival (Box Plot)

# %%
sns.boxplot(x='survived', y='fare', data=df)
plt.title("Fare Distribution by Survival")
plt.show()

# %%
# Survival by Class and Gender (Heatmap)

# %%
pivot=df.pivot_table(index='pclass',columns='sex',values='survived')
sns.heatmap(pivot,annot=True,cmap='Blues')
plt.title("Survival Rate by Class and Gender")
plt.show()
